# %%
import gmaps
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

csv_path = "../Project-1/EVstation_data.csv"

EVstation_data =pd.read_csv(csv_path)
EVstation_data
# Out:
#     state    zip   latitude   longitude
# 0      CA  91352  34.248319 -118.387971
# 1      CA  90024  34.052542 -118.448504
# 2      CA  91770  34.050745 -118.081014
# 3      CA  90015  34.040539 -118.271387
# 4      CA  90012  34.059133 -118.248589
# ..    ...    ...        ...         ...
# 195    AZ  86404  34.542170 -114.352870
# 196    AZ  85206  33.385361 -111.695062
# 197    AZ  85201  33.434313 -111.872266
# 198    AZ  85382  33.636921 -112.253682
# 199    AZ  85014  33.509862 -112.054162
#
# [200 rows x 4 columns]

# %%
lng = []
lat = []
coordinates = []

lng = EVstation_data["longitude"]
lat = EVstation_data["latitude"]

for i in range(len(lng)):
    
    coordinates.append(lat[i], lng[i])
    
    print(coordinates)
# Out:
# (34.2483191527193, -118.3879713743439)
# (34.052542, -118.448504)
# (34.050745, -118.081014)
# (34.040539, -118.271387)
# (34.059133, -118.248589)
# (33.759802, -118.096665)
# (38.576769, -121.495022)
# (33.770508, -118.265628)
# (34.30309, -118.480505)
# (34.066801, -118.227605)
# (34.036777, -118.368841)
# (34.06872, -118.064)
# (34.039736, -118.236065)
# (32.89947, -117.243)
# (33.098589, -117.004433)
# (34.221665, -118.468371)
# (33.909914, -117.459053)
# (34.14762, -118.147111)
# (34.145138, -118.152655)
# (34.145119, -118.150133)
# (34.142973, -118.140553)
# (34.118433, -118.149597)
# (33.7637, -118.192)
# (33.94325, -118.403342)
# (34.241116, -118.556708)
# (34.07122, -117.575)
# (34.228315, -119.170865)
# (33.824004, -116.543589)
# (37.700187, -121.876172)
# (34.0189, -117.38)
# (38.69005, -121.58889)
# (34.017081, -118.44704)
# (34.010021, -118.49583)
# (34.156839, -118.434454)
# (33.49605, -117.152)
# (34.138717, -118.35904)
# (34.21108, -118.448704)
# (33.94756, -118.153806)
# (37.80619, -122.4152)
# (38.599693, -121.427045)
# (37.784912, -122.430237)
# (37.792058, -122.404312)
# (37.78881, -122.401)
# (37.791791, -122.411265)
# (34.076264, -118.377527)
# (34.057657, -118.24789)
# (34.169242, -118.497212)
# (34.248959, -118.523887)
# (34.241687, -118.528543)
# (34.236853, -118.532588)
# (34.229277, -118.544827)
# (33.740758, -118.28192)
# (34.2924134, -118.4497914)
# (34.077588, -118.474585)
# (34.145528, -118.050548)
# (34.13556, -117.864)
# (33.9826, -118.3966)
# (34.029971, -118.385231)
# (33.777054, -117.870566)
# (34.16657601660278, -119.0458546627045)
# (33.919899, -117.898618)
# (34.192178, -118.934793)
# (34.418322, -119.3368)
# (34.105275, -117.809208)
# (34.147709, -118.136621)
# (34.05334473, -118.0841599)
# (34.267352, -119.2124)
# (34.268756, -119.2154)
# (34.268, -119.2492)
# (33.917593, -118.425334)
# (34.089085, -117.95463)
# (33.92364287667621, -118.1678308134918)
# (33.930663, -118.175758)
# (38.539336, -121.732405)
# (35.25939, -120.64492)
# (36.973393, -122.024849)
# (33.773005, -118.265821)
# (38.66292, -121.2634)
# (38.57277, -121.467902)
# (38.7042, -121.365)
# (38.615468, -121.517263)
# (38.552483, -121.4487)
# (38.524403, -121.5112)
# (38.73323, -120.78962)
# (38.356027, -121.9628)
# (38.36557, -121.967)
# (38.35172, -121.987)
# (38.356907, -122.001886)
# (38.355867, -121.9862)
# (38.351758, -121.994475)
# (38.682605, -121.297614)
# (38.457369, -121.842567)
# (38.72799, -120.828)
# (38.6476, -121.067)
# (38.40553, -121.391)
# (38.74453, -121.17)
# (38.618066, -121.334337)
# (38.15485, -121.69)
# (38.25281, -122.044229)
# (38.23723, -122.123)
# (38.105062, -122.265895)
# (33.944761, -118.399767)
# (38.35109, -121.993654)
# (38.578568, -121.491058)
# (34.059047, -118.256812)
# (34.033898, -118.256673)
# (34.081998, -118.21713)
# (33.799476, -118.257977)
# (34.208708, -118.444358)
# (34.241928, -118.390147)
# (47.044011, -122.822404)
# (45.508396, -122.664667)
# (39.15, -123.2091)
# (38.368755, -121.961192)
# (38.9412492, -121.1054805)
# (38.54643, -121.7388)
# (38.5443, -121.738)
# (38.544538, -121.749713)
# (38.55755, -121.6947)
# (38.569412, -121.721373)
# (36.188975, -121.075858)
# (33.84788, -118.13889)
# (37.94495, -122.5096)
# (37.7136, -122.2087)
# (47.443377, -122.296229)
# (43.608009, -116.197968)
# (44.99574, -123.019758)
# (45.508795, -122.8249)
# (38.2482, -122.0678)
# (37.77913, -122.418)
# (44.928439, -124.015824)
# (47.035421, -122.938962)
# (36.70104, -121.6673)
# (44.586123, -123.115389)
# (44.97604, -124.011459)
# (45.510465, -122.663354)
# (35.249929, -120.689683)
# (35.25982, -120.676)
# (47.673347, -117.388933)
# (47.654998, -117.425025)
# (32.236156, -110.781792)
# (44.009797, -123.033213)
# (34.44198, -119.829553)
# (45.522609, -122.988535)
# (45.520533, -122.978089)
# (47.614744, -122.193162)
# (45.509326, -122.666392)
# (40.74686, -111.876)
# (40.759561, -111.883924)
# (47.056888, -122.841752)
# (47.071917, -122.976675)
# (46.984193, -122.904856)
# (47.545324, -122.0195)
# (47.675897, -122.091237)
# (34.019875, -118.49151)
# (37.784871, -122.408991)
# (37.806798, -122.419488)
# (34.010528, -118.4898)
# (39.843886, -104.771138)
# (39.953798, -105.166116)
# (35.08847, -106.649567)
# (47.761878, -122.191915)
# (47.679224, -122.12995)
# (47.672359, -122.099034)
# (47.734211, -122.147041)
# (39.1458, -123.198497)
# (47.338754, -122.221114)
# (48.755607, -122.454132)
# (47.562162, -122.684286)
# (47.458466, -122.333257)
# (47.778229, -122.344838)
# (47.90272981640562, -122.2469883724914)
# (47.031067, -122.930247)
# (46.236607, -119.128998)
# (48.102863, -123.342273)
# (47.207367, -122.294997)
# (47.448354, -122.2188)
# (47.739021, -117.409937)
# (47.657264, -117.312518)
# (47.21978, -122.48576)
# (45.648094, -122.597954)
# (46.047464, -118.353406)
# (45.491783, -122.81107)
# (44.055213, -121.277279)
# (44.572608, -123.258425)
# (44.05902085037804, -123.0813974632293)
# (45.378967, -122.603899)
# (45.227394, -123.180863)
# (42.379969, -122.858192)
# (45.531759, -122.537403)
# (44.921582, -123.006236)
# (45.613979, -121.20996)
# (45.326814, -122.770853)
# (33.459826, -112.284168)
# (33.286316, -111.791107)
# (34.54217, -114.35287)
# (33.385361, -111.695062)
# (33.434313, -111.872266)
# (33.636921, -112.253682)
# (33.509862, -112.054162)

# %%
# Customize the size of the figure
figure_layout = {
    'width': '1200px',
    'height': '1200px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
EV_locations = coordinates

markers = gmaps.marker_layer(EV_locations)


# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/locations.py in locations_to_list(locations)
#      10     try:
# ---> 11         location_tuples = locations.itertuples()  # locations is a dataframe
#      12         locations_as_list = [
#
# AttributeError: 'tuple' object has no attribute 'itertuples'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5266746f71cd> in <module>
#       2 EV_locations = coordinates
#       3
# ----> 4 markers = gmaps.marker_layer(EV_locations)
#       5
#       6
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     551         A :class:`gmaps.Markers` instance.
#     552     """
# --> 553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/marker.py in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     313
#     314     marker_options = {
# --> 315         'location': locations_to_list(locations),
#     316         'hover_text': hover_text,
#     317         'label': label
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/locations.py in locations_to_list(locations)
#      15         ]
#      16     except AttributeError:
# ---> 17         locations_as_list = [
#      18             (latitude, longitude) for (latitude, longitude)
#      19             in locations
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/locations.py in <listcomp>(.0)
#      16     except AttributeError:
#      17         locations_as_list = [
# ---> 18             (latitude, longitude) for (latitude, longitude)
#      19             in locations
#      20         ]
#
# TypeError: cannot unpack non-iterable numpy.float64 object

# %%
coordinates.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e22ad4514140> in <module>
# ----> 1 coordinates.dtypes
#
# AttributeError: 'tuple' object has no attribute 'dtypes'
