# %%
import gmaps
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

csv_path = "../Project-1/EVstation_data.csv"

EVstation_data =pd.read_csv(csv_path)
EVstation_data
# Out:
#     state    zip   latitude   longitude
# 0      CA  91352  34.248319 -118.387971
# 1      CA  90024  34.052542 -118.448504
# 2      CA  91770  34.050745 -118.081014
# 3      CA  90015  34.040539 -118.271387
# 4      CA  90012  34.059133 -118.248589
# ..    ...    ...        ...         ...
# 195    AZ  86404  34.542170 -114.352870
# 196    AZ  85206  33.385361 -111.695062
# 197    AZ  85201  33.434313 -111.872266
# 198    AZ  85382  33.636921 -112.253682
# 199    AZ  85014  33.509862 -112.054162
#
# [200 rows x 4 columns]

# %%
lng = []
lat = []
coordinates = []

lng = EVstation_data["longitude"]
lat = EVstation_data["latitude"]

for i in range(len(lng)):
    
    coordinates.append([lat[i], lng[i]])
    
    print(coordinates)
# Out:
# [[34.2483191527193, -118.3879713743439]]
# [[34.2483191527193, -118.3879713743439], [34.052542, -118.448504]]
# [[34.2483191527193, -118.3879713743439], [34.052542, -118.448504], [34.050745, -118.081014]]
# [[34.2483191527193, -118.3879713743439], [34.052542, -118.448504], [34.050745, -118.081014], [34.040539, -118.271387]]
# [[34.2483191527193, -118.3879713743439], [34.052542, -118.448504], [34.050745, -118.081014], [34.040539, -118.271387], [34.059133, -118.248589]]
# [[34.2483191527193, -118.3879713743439], [34.052542, -118.448504], [34.050745, -118.081014], [34.040539, -118.271387], [34.059133, -118.248589], [33.759802, -118.096665]]
# [[34.2483191527193, -118.3879713743439], [34.052542, -118.448504], [34.050745, -118.081014], [34.040539, -118.271387], [34.059133, -118.248589], [33.759802, -118.096665], [38.576769, -121.495022]]
# ...

# %%
# Customize the size of the figure
figure_layout = {
    'width': '1200px',
    'height': '1200px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
EV_locations = coordinates

markers = gmaps.marker_layer(EV_locations)


# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='1200px', margin='0 auto 0 auto', padding='1px', w…

# %%
coordinates.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e22ad4514140> in <module>
# ----> 1 coordinates.dtypes
#
# AttributeError: 'tuple' object has no attribute 'dtypes'
